# %% [markdown]
# # Analyse play store dataset and write down conclusion of the analysis and also create plots if possible.

# %%
import pandas as pd

# %%
ps = pd.read_csv('googleplaystore.csv')

# %% [markdown]
# ## que1 :- Which category of apps has big count ?

# %%
ps['Category'].value_counts().index[0]
# Out:
# 'FAMILY'

# %% [markdown]
#
#
# ## que2 :- Top 5 Highest rating app from each category?

# %%
x = ps.groupby('Category').apply(lambda x: x.nlargest(5, 'Rating'))
x.reset_index(drop=True, inplace=True)
x
# Out:
#                                                    App        Category  \
# 0              Life Made WI-Fi Touchscreen Photo Frame             1.9
# 1              Spring flowers theme couleurs d t space  ART_AND_DESIGN
# 2                           Harley Quinn wallpapers HD  ART_AND_DESIGN
# 3                                    Cardi B Wallpaper  ART_AND_DESIGN
# 4    X Launcher Pro - IOS Style Theme & Control Center  ART_AND_DESIGN
# ..                                                 ...             ...
# 161                                   Weather forecast         WEATHER
# 162                                   Live Weather Pro         WEATHER
# 163                                   Weather Live Pro         WEATHER
# 164                         weather - weather forecast         WEATHER
# 165                      Fu*** Weather (Funny Weather)         WEATHER
#
#      Rating Reviews                Size    Installs  Type     Price  \
# ...

# %% [markdown]
# ## que3 :- Find number of free and paid apps.

# %%
ps['Type'].value_counts()
# Out:
# Free    10039
# Paid      800
# 0           1
# Name: Type, dtype: int64

# %% [markdown]
# ## que4 :- Number of highest rating apps?

# %%
ps[ps['Rating'] == 5.0]['Rating'].count()
# Out:
# 274

# %% [markdown]
# ## que5 :- Find the Category & ratings of apps which are paid.

# %%
ps[ps['Type'] == 'Paid'][['Category','Rating']]
# Out:
#                  Category  Rating
# 234              BUSINESS     4.7
# 235              BUSINESS     4.8
# 290              BUSINESS     4.7
# 291              BUSINESS     4.8
# 427         COMMUNICATION     4.0
# ...                   ...     ...
# 10735              FAMILY     NaN
# 10760  HEALTH_AND_FITNESS     4.4
# 10782                GAME     3.8
# 10785              FAMILY     4.2
# 10798              FAMILY     NaN
#
# [800 rows x 2 columns]

# %% [markdown]
# ## que 6 :- Find the name of the apps which has installed

# %%
ps
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
desrie_num = input("Enter how much plus installtion you want to Check")+'+'
ps[ps['Installs'] == desrie_num]['App']
# Out:
# Series([], Name: App, dtype: object)

# %% [markdown]
# # que7:- create your own question and solve them here.

# %% [markdown]
# ## 7.1 How Much Apps are Design for Teens?

# %%
ps[ps['Content Rating'] == 'Teen']['Content Rating'].count()
# Out:
# 1208

# %%
ps
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# ## 7.2 Name the app on which maximum Reviews are Recive ?

# %%
st = ps.sort_values(by='Reviews',ascending=False)
st
# Out:
#                                     App             Category  Rating Reviews  \
# 2989             GollerCepte Live Score               SPORTS     4.2    9992
# 4970       Ad Block REMOVER - NEED ROOT                TOOLS     3.3     999
# 2723                SnipSnap Coupon App             SHOPPING     4.2    9975
# 2705                SnipSnap Coupon App             SHOPPING     4.2    9975
# 3079  US Open Tennis Championships 2018               SPORTS     4.0    9971
# ...                                 ...                  ...     ...     ...
# 7217                          CE-STRONG               FAMILY     NaN       0
# 6492                   Anime Mod for BM  BOOKS_AND_REFERENCE     NaN       0
# 7221                  CE-SETRAM l’Appli   LIBRARIES_AND_DEMO     NaN       0
# 5480           Glanceable Ap Watch Face      PERSONALIZATION     NaN       0
# 4177                    G-NetReport Pro                TOOLS     NaN       0
#
# ...

# %%
ps[ps['Reviews'] == ps['Reviews'].max()].value_counts()
# Out:
# App                     Category  Rating  Reviews  Size  Installs    Type  Price  Content Rating  Genres  Last Updated  Current Ver  Android Ver
# GollerCepte Live Score  SPORTS    4.2     9992     31M   1,000,000+  Free  0      Everyone        Sports  May 23, 2018  6.5          4.1 and up     1
# dtype: int64
